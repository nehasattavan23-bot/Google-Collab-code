# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a|b
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,2,5}
a-b
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.difference(b)
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.symmetric_difference(b)
# Out:
# {1, 4, 5, 7}

# %%
dct={1:"shreya",2:"pallavi",3:"swara",4:"tanu",5:"janhavi"}
for i,j in dct.items():
  print(i,j)
# Out:
# 1 shreya
# 2 pallavi
# 3 swara
# 4 tanu
# 5 janhavi

# %%
sample={"days":["mon","tue","wed","thu",],
        "planets":["sun","saturn","earth"]}
for key,values in sample.items():
  print(values)
# Out:
# ['mon', 'tue', 'wed', 'thu']
# ['sun', 'saturn', 'earth']

# %%
n=int(input())
for row in range(n):
    for col in range(n):
      ele=max(row+1,col+1,n-row,n-col)
      print(ele,end=" ")
    print()
# Out:
# 5
# 5 5 5 5 5
# 5 4 4 4 5
# 5 4 3 4 5
# 5 4 4 4 5
# 5 5 5 5 5

# %%
num=(input("enter a number"))
i=len(num)-1
while i>=0:
  print(num[i],end=" ")
  i-=1
# Out:
# enter a number1234
# 4 3 2 1
